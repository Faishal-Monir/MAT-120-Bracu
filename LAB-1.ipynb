# %% [markdown]
# <h1><b>#Lab-1<br>--> Marks Distribution !<b> </h1>
# <hr><h2><b>Attendence-5<br>
# Assignment-5<br>
# Final-10<b></h2>
# <hr>

# %%
#https://www.halvorsen.blog/documents/programming/python/resources/powerpoints/Numerical%20Differentiation%20in%20Python.pdf

# %%
import numpy as np

# %%
#returns the conjugate of the imaginary number
x=3+2j
print(np.conj(x))
# Out:
# (3-2j)
